# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamilo1133/data-science-bootcamp/blob/main/02_pandas_intro_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data=[12,12,32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
df = pd.DataFrame(data=[12,12,32], index=['first', 'second','third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
df = pd.DataFrame(data={'WIG20':['PKN ORLEN','PKO BP'],
                        'mWIG40':['Amica','Playway']})
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data=[[10,12,13],[23,12,10]], index=['first','second',],  columns=['col_1','col_2','col_3'])

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.values
# Out:
# array([[10, 12, 13],
#        [23, 12, 10]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
df.describe()
# Out:
#            col_1  col_2     col_3
# count   2.000000    2.0   2.00000
# mean   16.500000   12.0  11.50000
# std     9.192388    0.0   2.12132
# min    10.000000   12.0  10.00000
# 25%    13.250000   12.0  10.75000
# 50%    16.500000   12.0  11.50000
# 75%    19.750000   12.0  12.25000
# max    23.000000   12.0  13.00000

# %%
df.describe().T
# Out:
#        count  mean       std   min    25%   50%    75%   max
# col_1    2.0  16.5  9.192388  10.0  13.25  16.5  19.75  23.0
# col_2    2.0  12.0  0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  11.5  2.121320  10.0  10.75  11.5  12.25  13.0

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df['col_1']
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
type(df['col_1'])
# Out:
# pandas.core.series.Series

# %%
df[['col_1']]
# Out:
#         col_1
# first      10
# second     23

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.columns = ['a', 'b', 'c']
df
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
df.a
# Out:
# first     10
# second    23
# Name: a, dtype: int64

# %%
df.b
# Out:
# first     12
# second    12
# Name: b, dtype: int64

# %%
df.columns = ['a', 'sprzedaz grudzien', 'c']
df
# Out:
#          a  sprzedaz grudzien   c
# first   10                 12  13
# second  23                 12  10

# %%
df.sprzedaz grudzien
# Out:
#   File "<ipython-input-66-ef086b1a6a4e>", line 1
#     df.sprzedaz grudzien
#                 ^
# SyntaxError: invalid syntax

# %%
df.sprzedaz_grudzien
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-ab5b94a77ccc> in <cell line: 0>()
# ----> 1 df.sprzedaz_grudzien
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'sprzedaz_grudzien'

# %%
df['d'] = df.a + df.c

# %%
df
# Out:
#          a  sprzedaz grudzien   c   d
# first   10                 12  13  23
# second  23                 12  10  33

# %%
df = pd.DataFrame(data=[[10,12,13],[23,12,10]], index=['first','second',],  columns=['col_1','col_2','col_3'])

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.loc['first']
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
type(df.loc['first'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.iloc[0].T
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.loc['first', 'col_2']
# Out:
# np.int64(12)

# %%
df.loc[:, 'col_2']
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64

# %%
df.iloc[0,1]
# Out:
# np.int64(12)
